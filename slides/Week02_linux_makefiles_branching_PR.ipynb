# %% [markdown]
# # ![image](images/uva-icon-57x57.png) DS5111 Software and Automation Skills
#
# |  |
# | :--: |
# | $School\ of\ Data Science$ |
# | $University\ of\ Virginia$ |

# %% [markdown]
# # ![image](images/uva-icon-57x57.png) Announcements/Questions
#
#
# ## Notes
#  * Adjusting class lectures... should have next 2 or 3 modules out soon.

# %% [markdown]
# # ![image](images/uva-icon-57x57.png) Topics for goals for this week:
#
# ### Linux overview
#
# ### Makefiles
#
# ### Quick Demo of Pipeline
#
# ### Branching with git
#
# ### Hands-on playing with std.stdout
#
#
# ### This weeks LAB:
# * Create a script to pre validate youtube ids
# * The script will be written in python but should play nice with linux pipes

# %% [markdown]
# # ![image](images/uva-icon-57x57.png)  Linux CLI
# Think of like the old CLI games
#
# ## Where Am I?
# * **pwd**      # where am I
#
# ## What is around me?
# * **ls**       # think of it as 'light source'
#
# ## How do I move around?
# * **cd**       # go to directory
#
# ### Important shorthand/symbols
# * **`.`**      # Here
# * **`..`**     # UP one level
# * **`~`**      # HOME
#
# ## How do I interact with the environment?
# * **cat**      # SEE INSIDE files
# * **nano**     # EDIT the contents of a file

# %% [markdown]
# # ![image](images/uva-icon-57x57.png)  Linux general tips
#
# # ls flags
# * `ls -la` -> `l = list, a = all`
#
# # Alias
# * `alias ll='ls -la'` makes a new command `ll`
#
# # `.bash_profile`, `.bashrc`
# These files are usually read on entry into shell
# * Stores variables for use in shell
# * This is a good place your aliases
#
# # cd shortcut
# * **cd -** the `-` is not for a flag, it IS the flag in this case.  It takes you back to the previous directory
# * **cd** by itself always takes you home, i.e. `~`, in our case `/home/ubuntu/`
#
# ## Creating and deleting files/folders
# * **touch**     # creates an empty file, or if it exists, updates the timestamp that indicates when it was created
# * **mkdir**     # create a directory
# * mkdir -p  # createa a directory with subdirectories
#
#
# ## Making files executable
# * **chmod + <filename>**
# * **shebang -> #!/bin** You can call an inerpreter/program or you can embed it's location inside the script

# %% [markdown]
# # ![image](images/uva-icon-57x57.png) Autocomplete
# **NOTE:**  Use **autocomplete** as much as possible, it's a habit that will save you lots of time in the long run.
#
# ## = EFFICIENCY: Leverage automation/process as much as possible =
#
# ## Example
# Assume we have some files and a directory like:
# ```
# pipeline/
# ├── crontab_template.txt
# ├── data
# │   ├── processing
# │   └── watch_dir
# ├── logs
# │   └── pipeline_audit.log
# └── scripts
#     ├── clean_ids.py
#     ├── fetch_transcripts.py
#     ├── load_snowflake.py
#     └── orchestrator.sh
# ```
#
# * **cd pipe<tab>** will autocomplete to **cd pipeline/**
# * **cd pipeline/sc<tab>** will autocomplete to **cd pipeline/scripts/**
#
# ### USE THE FEEDBACK
# * If **<TAB>** doesn't expand, **check for a typo**
# * OR... it needs more chars to differentiate.
#     - A file and directory with same name
#     - Or **pipeline** versus **pipecleaner**.  Then **cd pipe<tab>** needs the **c** or the **l** to auto expand**

# %% [markdown]
# # ![image](images/uva-icon-57x57.png) vim
# Very Quick Demo on Vim
# * Vim is hard to get at first
# * Once you get it, Vim is hard to let go of
#
# * Efficient
# * Stay focused, i.e. do not break context
# * The basic keystrokes are supported in most IDEs

# %% [markdown]
# # ![image](images/uva-icon-57x57.png) Makefiles
# Let's play with makefiles first hand to get a feel for them
#
# Use **nano** and create a makefile.  Create a job called `job1` -> `echo hello world`
# * Make sure you use **<TAB>>**
#
# * Run `make` -> we get the echo!
#
# * Silence the echo with `@`
#
# * IF you want to avoid unintended consequences, use a simple default.
# This has worked for me, it also acts like a 'help' flag.
# ```
# default:
#     @cat makefile
# ```
#
# ## Chain jobs
#
# ## Make looks for a name, in a file or directory
# **NB:** This is why we can call `env` over and over, it will only run the **first time**
#
# ## To be proper, use `.PHONY`
# However, we'd have a conflict because `.PHONY` indicates it should run always.  So use as needed.
#
# ## Branching can get as deep as you want, as long as its a DAG (Directed Acyclic Graph)
# * **Very useful** for local pipelines!  IF each step creates an artifact, you can use that to keep steps from running again.
#
# ## Example:
# |             | STEP 1          | STEP 2          | STEP 3                | STEP 4         |
# | --          | --              | --              | --                    | --             |
# | Description |  download data  | clean data      | run model             | inspect output |
# | generates   |  `rawdata/`     | `cleandata.csv` | `classifications.csv` | `analysis.csv` |

# %% [markdown]
# # ![image](images/uva-icon-57x57.png)  Makefiles - beyond automation
# Using `makefile` has some good bonus side effects
#
# One of the underlying themes of the course:
# ## EAGLESON'S LAW
# **"Any code of your own that you haven't looked at for six or more months might as well have been written by someone else."**
#
# ## Documentation
# - How to use flags to run your scripts
# - Tells **OTHERS** how to run your scripts
# - Preserves the order, flow of operations
#
# ## Environment
# * The setup sequence insured you follow the same procedure when you recreate an environment
#
# ## Pull requests
# * **THIS IS A BIG ONE**  Have a code reviewer pull and run the jobs for new features and tests
#     - I can't tell you how many bugs and `oops, I forgot this file` issues this way!!!

# %% [markdown]
# # ![image](images/uva-icon-57x57.png)  Github branching
#
# Our first foray into git will be to set up our process for branching.
#
# ## Create a branch
# `git checkout -b my_new_branch` creates a new branch.
# * You only need the -b the first time!  Henceforth `git checkout my_branch` switchees to the branch.
#
# ## See what branches you have
# `git branch` will show you local branches.
# * But what if there is a new branch in github?  `git branch -r` will list local AND remote branches.
#
# ## I want to use a branch on github that is not on my local.
# Execute a `git pull` (synchronize to github first), then `git checkout new_branch`
#
# ## As long as there is no conflict, files edited in two branches..
# You can switch between branches using `git branch A` and `git branch B` back and forth.
#
# ## When you are ready to commit files
# * `git add myfile` OR `git add .` to add all files (carefull!)
# * I always to a `git status` in between steps to make sure things are ok... after an add, the files should show up as green.
# * `git commit -m "<commit message>"`  to commit, finalize.  With the -m flag you can enter a message in the same stroke.
# * At this point git status should show all good, and one commit ahead.
# * `git push` to sync your code to the remote.  Changes should now be visible in the github UI.
#
# ## Some useful commands
# * `git status`
#     - Will report all good status if everything is as expected
#     - Will show you what is modified, what is staged
#     - Will also show you `all good` locally, but remind you that you are one commit ahead/behind the remote.
# * `git log` to see previous commits

# %% [markdown]
# # ![image](images/uva-icon-57x57.png) Creating a PR
# I'll demo how from the UI -> [my github repo](https://github.com/EfrainOlivaresUVA/2508_DS5111_dpy8wq)
#
# Probably a good idea to clone the shared repository to the VM, so you can get scripts like the headless-browser on it.  Then just copy and execute.
#
# ## Checklist for PRs
# * The six-month-rule, which we'll use everywhere should be applied here as well!
# * Write a terse, direct, but informative description of what the PR is about.  Please do not leave it blank, and please do not just write write `Lab 1`.  On the other hand, keep it down to as few words as possible.  **THIS IS A CHALLENGE**, it sounds easy but it takes practice to think and write this way.
# * Always include the source of the request.  In our world, that would be a link to the lab itself.
# * Include how you know you're done.  In the corporate world, and later in ours, it means what tests ran, or how you tested it.
#
# Add any other instruction and comments you think are relevant.

# %% [markdown]
# # ![image](images/uva-icon-57x57.png)  This weeks LAB
#
# You'll build a 'simple' file that takes youtube ids at the console, and filters out bad ids.
